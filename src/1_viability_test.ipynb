# %% [markdown]
# # Bibliotecas usadas

# %%
import pandas as pd
import numpy as np
import sweetviz as sv
import pickle as pkl

from dython.nominal import associations

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Carregamento da base pré-preocessada

# %%
df = pkl.load(open("../data/files/Normalized_Data.pkl", "rb"))

# %% [markdown]
# # Separação da base em treino e teste (80% x 20%)

# %%
X = df.drop(columns = ["attack_cat", "Label"])
y = df[["attack_cat", "Label"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.2, random_state = 42)

# %%
del df, X, y

# %% [markdown]
# # Seleção de características para classificação binária

# %% [markdown]
# ## A seleção de características se dará com base na média da importância das características dos modelos Adaptive Boosting, Gradient Boosting e Random Forest

# %% [markdown]
# ## Adaboost

# %%
ada_boost = AdaBoostClassifier(algorithm = "SAMME", random_state = 42)

ada_boost.fit(X_train, y_train["Label"])
# Out:
# AdaBoostClassifier(algorithm='SAMME', random_state=42)

# %%
y_predicted = ada_boost.predict(X_test)

train_accuracy = ada_boost.score(X_train, y_train["Label"])
test_accuracy = accuracy_score(y_test["Label"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["Label"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")
# Out:
# Acurácia no treino 0.9899182425427487
# Acurácia no teste: 0.9896930594684484
# Acurácia balanceada no teste: 0.9784115951926249

# %%
feature_importance_ada_boost = pd.DataFrame({"Feature": ada_boost.feature_names_in_, 
                                             "Feature_Importance": ada_boost.feature_importances_})

# %% [markdown]
# ## Gradient Boosting

# %%
gradient_boosting = GradientBoostingClassifier(random_state = 42)

gradient_boosting.fit(X_train, y_train["Label"])
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_predicted = gradient_boosting.predict(X_test)

train_accuracy = gradient_boosting.score(X_train, y_train["Label"])
test_accuracy = accuracy_score(y_test["Label"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["Label"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")
# Out:
# Acurácia no treino 0.9926688626133515
# Acurácia no teste: 0.9924394772357558
# Acurácia balanceada no teste: 0.9835877371034568

# %%
feature_importance_gradient_boosting = pd.DataFrame({"Feature": gradient_boosting.feature_names_in_,
                                                     "Feature_Importance": gradient_boosting.feature_importances_})

# %% [markdown]
# ## Random Forest

# %%
random_forest = RandomForestClassifier(random_state = 42)

random_forest.fit(X_train, y_train["Label"])
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_predicted = random_forest.predict(X_test)

train_accuracy = random_forest.score(X_train, y_train["Label"])
test_accuracy = accuracy_score(y_test["Label"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["Label"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")
# Out:
# Acurácia no treino 0.9999989501450112
# Acurácia no teste: 0.9961433617476287
# Acurácia balanceada no teste: 0.9909995206423241

# %%
feature_importance_random_forest = pd.DataFrame({"Feature": random_forest.feature_names_in_, 
                                                 "Feature_Importance": random_forest.feature_importances_})

# %% [markdown]
# ## Média das importâncias das características
#
# ### Características mais importantes: dstip, ct_state_ttl, ct_dst_sport_ltm, sttl, dsport e sbytes

# %%
df_feature_importance = pd.concat([feature_importance_ada_boost, feature_importance_gradient_boosting, feature_importance_random_forest], axis = 1)
df_feature_importance.columns = ["Feature", "Feature_Importance_Ada_Boost", 
                                 "Feature", "Feature_Importance_Gradient_Boosting",
                                 "Feature", "Feature_Importance_Random_Forest"]

df_feature_importance = df_feature_importance.iloc[:, [0, 1, 3, 5]]

df_feature_importance["Mean"] = df_feature_importance.iloc[:, [1, 2, 3]].mean(axis = 1)

df_feature_importance.sort_values(by = "Mean", ascending = False)
# Out:
#              Feature  Feature_Importance_Ada_Boost  \
# 2              dstip                      0.125444
# 36      ct_state_ttl                      0.035253
# 7             sbytes                      0.122702
# 3             dsport                      0.196853
# 1              sport                      0.190642
# 9               sttl                      0.048663
# 41        ct_srv_dst                      0.098012
# 8             dbytes                      0.071094
# 22           smeansz                      0.000000
# 13           service                      0.037726
# 45  ct_dst_sport_ltm                      0.022299
# 14             Sload                      0.000000
# 25       res_bdy_len                      0.037021
# 0              srcip                      0.000000
# 17             Dpkts                      0.000000
# 44  ct_src_dport_ltm                      0.014290
# 23           dmeansz                      0.000000
# 46    ct_dst_src_ltm                      0.000000
# 33            synack                      0.000000
# 40        ct_srv_src                      0.000000
# 10              dttl                      0.000000
# 42        ct_dst_ltm                      0.000000
# 4              proto                      0.000000
# 32            tcprtt                      0.000000
# 18              swin                      0.000000
# 43       ct_src_ ltm                      0.000000
# 34            ackdat                      0.000000
# 29             Ltime                      0.000000
# 28             Stime                      0.000000
# 15             Dload                      0.000000
# 16             Spkts                      0.000000
# 11             sloss                      0.000000
# 26              Sjit                      0.000000
# 31           Dintpkt                      0.000000
# 6                dur                      0.000000
# 30           Sintpkt                      0.000000
# 12             dloss                      0.000000
# 27              Djit                      0.000000
# 20             stcpb                      0.000000
# 21             dtcpb                      0.000000
# 19              dwin                      0.000000
# 5              state                      0.000000
# 37  ct_flw_http_mthd                      0.000000
# 24       trans_depth                      0.000000
# 35   is_sm_ips_ports                      0.000000
# 39        ct_ftp_cmd                      0.000000
# 38      is_ftp_login                      0.000000
#
#     Feature_Importance_Gradient_Boosting  Feature_Importance_Random_Forest  \
# 2                           7.648476e-01                          0.131987
# 36                          1.519812e-01                          0.170776
# 7                           2.474145e-03                          0.103436
# 3                           1.482632e-02                          0.012410
# 1                           2.719971e-03                          0.013567
# 9                           2.095638e-03                          0.121960
# 41                          9.096191e-03                          0.020356
# 8                           7.400166e-03                          0.023528
# 22                          7.485812e-03                          0.050762
# 13                          5.005015e-03                          0.015269
# 45                          1.194590e-04                          0.024391
# 14                          1.121976e-05                          0.040686
# 25                          7.965873e-04                          0.001231
# 0                           7.712250e-09                          0.036312
# 17                          6.297156e-06                          0.029001
# 44                          1.953907e-05                          0.011556
# 23                          2.723324e-03                          0.022619
# 46                          1.282411e-03                          0.022067
# 33                          1.267582e-02                          0.006584
# 40                          1.273242e-04                          0.016163
# 10                          1.833585e-03                          0.013836
# 42                          2.371988e-05                          0.012545
# 4                           2.143927e-05                          0.009675
# 32                          3.512260e-03                          0.006172
# 18                          7.704518e-03                          0.001877
# 43                          4.187517e-06                          0.009511
# 34                          1.406805e-04                          0.007029
# 29                          4.866166e-05                          0.007101
# 28                          4.988915e-05                          0.006823
# 15                          0.000000e+00                          0.006130
# 16                          3.903181e-05                          0.005452
# 11                          3.801512e-05                          0.005171
# 26                          3.254977e-05                          0.004202
# 31                          3.954516e-04                          0.003797
# 6                           1.088858e-05                          0.003870
# 30                          6.049639e-06                          0.003803
# 12                          3.472854e-04                          0.003412
# 27                          9.404640e-06                          0.003182
# 20                         -8.261416e-13                          0.002565
# 21                          4.916325e-06                          0.002517
# 19                          0.000000e+00                          0.002334
# 5                           0.000000e+00                          0.001896
# 37                          8.343052e-05                          0.001474
# 24                          0.000000e+00                          0.000773
# 35                          0.000000e+00                          0.000097
# 39                          0.000000e+00                          0.000071
# 38                          0.000000e+00                          0.000029
#
#         Mean
# 2   0.340759
# 36  0.119337
# 7   0.076204
# 3   0.074696
# 1   0.068976
# 9   0.057573
# 41  0.042488
# 8   0.034008
# 22  0.019416
# 13  0.019333
# 45  0.015603
# 14  0.013566
# 25  0.013016
# 0   0.012104
# 17  0.009669
# 44  0.008622
# 23  0.008448
# 46  0.007783
# 33  0.006420
# 40  0.005430
# 10  0.005223
# 42  0.004190
# 4   0.003232
# 32  0.003228
# 18  0.003194
# 43  0.003172
# 34  0.002390
# 29  0.002383
# 28  0.002291
# 15  0.002043
# 16  0.001830
# 11  0.001736
# 26  0.001412
# 31  0.001398
# 6   0.001293
# 30  0.001270
# 12  0.001253
# 27  0.001064
# 20  0.000855
# 21  0.000841
# 19  0.000778
# 5   0.000632
# 37  0.000519
# 24  0.000258
# 35  0.000032
# 39  0.000024
# 38  0.000010

# %% [markdown]
# # Seleção de características para classificação multiclasse

# %% [markdown]
# ## A seleção de características se dará com base na média da importância das características dos modelos Adaptive Boosting, Gradient Boosting e Random Forest
#
# ### Pela exploração da base e pelos resultados gerados, conclui-se que a base não modela bem o problema da identificação de qual ataque foi feito, mas somente se foi ataque ou não

# %% [markdown]
# ## Adaboost

# %%
ada_boost = AdaBoostClassifier(algorithm = "SAMME", random_state = 42)

ada_boost.fit(X_train, y_train["attack_cat"])
# Out:
# AdaBoostClassifier(algorithm='SAMME', random_state=42)

# %%
y_predicted = ada_boost.predict(X_test)

train_accuracy = ada_boost.score(X_train, y_train["attack_cat"])
test_accuracy = accuracy_score(y_test["attack_cat"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["attack_cat"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")
# Out:
# Acurácia no treino 0.9683788650446081
# Acurácia no teste: 0.967982724647495
# Acurácia balanceada no teste: 0.4412057679531145

# %%
feature_importance_ada_boost = pd.DataFrame({"Feature": ada_boost.feature_names_in_, 
                                             "Feature_Importance": ada_boost.feature_importances_})

# %% [markdown]
# ## Gradient Boosting

# %%
gradient_boosting = GradientBoostingClassifier(random_state = 42)

gradient_boosting.fit(X_train, y_train["attack_cat"])

# %%
y_predicted = gradient_boosting.predict(X_test)

train_accuracy = gradient_boosting.score(X_train, y_train["attack_cat"])
test_accuracy = accuracy_score(y_test["attack_cat"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["attack_cat"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")

# %%
feature_importance_gradient_boosting = pd.DataFrame({"Feature": gradient_boosting.feature_names_in_,
                                                     "Feature_Importance": gradient_boosting.feature_importances_})

# %% [markdown]
# ## Random Forest

# %%
random_forest = RandomForestClassifier(random_state = 42)

random_forest.fit(X_train, y_train["attack_cat"])
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_predicted = random_forest.predict(X_test)

train_accuracy = random_forest.score(X_train, y_train["attack_cat"])
test_accuracy = accuracy_score(y_test["attack_cat"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["attack_cat"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")
# Out:
# Acurácia no treino 0.9911369287908084
# Acurácia no teste: 0.983435267624265
# Acurácia balanceada no teste: 0.570729716778857

# %%
feature_importance_random_forest = pd.DataFrame({"Feature": random_forest.feature_names_in_, 
                                                 "Feature_Importance": random_forest.feature_importances_})

# %%
confusion_matrix_ada_boost = confusion_matrix(y_test["attack_cat"], y_predicted)
ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_ada_boost, display_labels = random_forest.classes_).plot()

# %% [markdown]
# ## Média das importâncias das características
#
# ### Características mais importantes: dstip, ct_state_ttl, ct_dst_sport_ltm, sttl, dsport e sbytes

# %%
df_feature_importance = pd.concat([feature_importance_ada_boost, feature_importance_random_forest], axis = 1)
df_feature_importance.columns = ["Feature", "Feature_Importance_Ada_Boost", 
                                 "Feature", "Feature_Importance_Random_Forest"]

df_feature_importance = df_feature_importance.iloc[:, [0, 1, 3]]

df_feature_importance["Mean"] = df_feature_importance.iloc[:, [1, 2]].mean(axis = 1)

df_feature_importance.sort_values(by = "Mean", ascending = False)
# Out:
#              Feature  Feature_Importance_Ada_Boost  \
# 2              dstip                      0.132337
# 1              sport                      0.228577
# 7             sbytes                      0.105115
# 3             dsport                      0.194074
# 36      ct_state_ttl                      0.035023
# 9               sttl                      0.058271
# 41        ct_srv_dst                      0.100824
# 8             dbytes                      0.055250
# 22           smeansz                      0.015000
# 0              srcip                      0.000000
# 45  ct_dst_sport_ltm                      0.022159
# 13           service                      0.020906
# 14             Sload                      0.000000
# 17             Dpkts                      0.000000
# 46    ct_dst_src_ltm                      0.000000
# 23           dmeansz                      0.000000
# 44  ct_src_dport_ltm                      0.012708
# 25       res_bdy_len                      0.019755
# 40        ct_srv_src                      0.000000
# 10              dttl                      0.000000
# 42        ct_dst_ltm                      0.000000
# 4              proto                      0.000000
# 34            ackdat                      0.000000
# 29             Ltime                      0.000000
# 28             Stime                      0.000000
# 43       ct_src_ ltm                      0.000000
# 15             Dload                      0.000000
# 16             Spkts                      0.000000
# 33            synack                      0.000000
# 32            tcprtt                      0.000000
# 11             sloss                      0.000000
# 26              Sjit                      0.000000
# 12             dloss                      0.000000
# 30           Sintpkt                      0.000000
# 31           Dintpkt                      0.000000
# 18              swin                      0.000000
# 6                dur                      0.000000
# 27              Djit                      0.000000
# 21             dtcpb                      0.000000
# 5              state                      0.000000
# 20             stcpb                      0.000000
# 19              dwin                      0.000000
# 37  ct_flw_http_mthd                      0.000000
# 24       trans_depth                      0.000000
# 35   is_sm_ips_ports                      0.000000
# 39        ct_ftp_cmd                      0.000000
# 38      is_ftp_login                      0.000000
#
#     Feature_Importance_Random_Forest      Mean
# 2                           0.129689  0.131013
# 1                           0.015328  0.121952
# 7                           0.122001  0.113558
# 3                           0.012627  0.103351
# 36                          0.142752  0.088888
# 9                           0.111799  0.085035
# 41                          0.018871  0.059847
# 8                           0.024783  0.040017
# 22                          0.056262  0.035631
# 0                           0.050175  0.025087
# 45                          0.027329  0.024744
# 13                          0.015514  0.018210
# 14                          0.032909  0.016454
# 17                          0.029680  0.014840
# 46                          0.025651  0.012826
# 23                          0.023387  0.011694
# 44                          0.009896  0.011302
# 25                          0.001326  0.010540
# 40                          0.015007  0.007504
# 10                          0.014244  0.007122
# 42                          0.013250  0.006625
# 4                           0.012504  0.006252
# 34                          0.009260  0.004630
# 29                          0.006700  0.003350
# 28                          0.006626  0.003313
# 43                          0.006090  0.003045
# 15                          0.005834  0.002917
# 16                          0.005605  0.002803
# 33                          0.005448  0.002724
# 32                          0.005336  0.002668
# 11                          0.004765  0.002383
# 26                          0.004450  0.002225
# 12                          0.004222  0.002111
# 30                          0.004159  0.002080
# 31                          0.003777  0.001888
# 18                          0.003580  0.001790
# 6                           0.003334  0.001667
# 27                          0.003160  0.001580
# 21                          0.002615  0.001307
# 5                           0.002483  0.001242
# 20                          0.002433  0.001216
# 19                          0.002324  0.001162
# 37                          0.001736  0.000868
# 24                          0.000860  0.000430
# 35                          0.000140  0.000070
# 39                          0.000047  0.000024
# 38                          0.000032  0.000016

# %% [markdown]
# # Execução dos modelos escolhidos | Classificação binária

# %% [markdown]
# ## Separa-se o conjunto de dados com as características mais importantes

# %%
X_train = X_train[["dstip", "ct_state_ttl", "ct_dst_sport_ltm", "sttl", "dsport", "sbytes"]]
X_test = X_test[["dstip", "ct_state_ttl", "ct_dst_sport_ltm", "sttl", "dsport", "sbytes"]]

# %%
mlp = MLPClassifier(random_state = 42)

mlp.fit(X_train, y_train["Label"])
y_predicted = mlp.predict(X_test)

train_accuracy = mlp.score(X_train, y_train["Label"])
test_accuracy = accuracy_score(y_test["Label"], y_predicted)
test_balanced_accuracy = balanced_accuracy_score(y_test["Label"], y_predicted)

print(f"Acurácia no treino {train_accuracy} \nAcurácia no teste: {test_accuracy} \nAcurácia balanceada no teste: {test_balanced_accuracy}")
# Out:
# Acurácia no treino 0.9870222175562
# Acurácia no teste: 0.9867419201932571
# Acurácia balanceada no teste: 0.9888442274056229
